# %%
# !pip install leidenalg

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from pathlib import Path
from statistics import median
import gzip
import scipy.io
import scanpy as sc

# %% [markdown]
# # Part 1. Load and filter data

# %%
filename = "GSE89567_IDH_A_processed_data.txt.gz"
raw = pd.read_csv(filename, compression='gzip', sep='\t', index_col=0)
raw
# Out:
#             MGH42_P7_A01  MGH42_P7_A02  MGH42_P7_A03  MGH42_P7_A04  \
# 'A1BG'           1.19280      0.000000       0.00000       0.00000
# 'A1BG-AS1'       0.00000      0.000000       0.00000       0.00000
# 'A1CF'           0.00000      0.094912       0.00000       0.00000
# 'A2M'            7.04390      7.609500       0.77062       7.61460
# 'A2M-AS1'        0.00000      0.000000       0.00000       0.00000
# ...                  ...           ...           ...           ...
# 'ZYG11A'         0.00000      0.370720       0.47508       0.15056
# 'ZYG11B'         0.27143      0.444670       3.13260       1.48650
# 'ZYX'            2.70580      2.107700       0.00000       3.84590
# 'ZZEF1'          0.71370      1.143400       0.00000       0.00000
# 'ZZZ3'           0.00000      0.000000       3.34040       0.00000
#
#             MGH42_P7_A05  MGH42_P7_A07  MGH42_P7_A09  MGH42_P7_A11  \
# 'A1BG'           0.00000       0.66903       0.00000       0.00000
# 'A1BG-AS1'       0.00000       0.00000       0.00000       0.00000
# 'A1CF'           0.00000       0.00000       0.00000       0.00000
# 'A2M'            0.00000       0.00000       0.27501       8.16240
# 'A2M-AS1'        2.03390       2.39420       0.00000       0.00000
# ...                  ...           ...           ...           ...
# 'ZYG11A'         0.47508       0.26063       0.15704       0.26664
# 'ZYG11B'         4.03830       2.00580       2.73880       0.70399
# 'ZYX'            3.82720       3.21550       3.23450       3.17860
# 'ZZEF1'          1.55140       1.16220       2.32280       2.37380
# 'ZZZ3'           4.88400       3.70110       0.00000       0.00000
#
#             MGH42_P7_A12  MGH42_P7_B02  ...  MGH107neg_P2_E06  \
# 'A1BG'           0.00000       0.00000  ...           0.00000
# 'A1BG-AS1'       0.00000       0.00000  ...           0.00000
# 'A1CF'           0.00000       0.00000  ...           0.00000
# 'A2M'            6.56550       6.96580  ...           0.00000
# 'A2M-AS1'        0.00000       0.00000  ...           0.00000
# ...                  ...           ...  ...               ...
# 'ZYG11A'         0.34483       0.24610  ...           0.25580
# 'ZYG11B'         0.10299       0.13356  ...           0.16864
# 'ZYX'            1.13420       0.43082  ...           3.86430
# 'ZZEF1'          0.45312       2.04090  ...           0.10702
# 'ZZZ3'           0.00000       0.63320  ...           0.00000
#
#             MGH107pos_P2_B03  MGH107neg_P1_F03  MGH107neg_P1_G06  \
# 'A1BG'               0.00000           0.00000           0.00000
# 'A1BG-AS1'           0.00000           0.00000           0.00000
# 'A1CF'               0.00000           0.00000           0.00000
# 'A2M'                8.60460           0.00000           0.00000
# 'A2M-AS1'            0.00000           0.00000           0.00000
# ...                      ...               ...               ...
# 'ZYG11A'             0.13225           0.50080           0.31383
# 'ZYG11B'             0.45101           0.20414           0.45733
# 'ZYX'                0.00000           0.00000           0.00000
# 'ZZEF1'              0.00000           3.08370           2.23760
# 'ZZZ3'               0.00000           0.64339           0.00000
#
#             MGH107neg_P2_H03  MGH107neg_P2_C05  MGH107pos_P2_D07  \
# 'A1BG'               0.00000           0.00000           0.00000
# 'A1BG-AS1'           0.00000           0.83996           0.00000
# 'A1CF'               0.00000           0.00000           0.00000
# 'A2M'                0.00000           0.00000           9.52810
# 'A2M-AS1'            0.00000           0.00000           0.00000
# ...                      ...               ...               ...
# 'ZYG11A'             0.50691           0.17505           0.13225
# 'ZYG11B'             0.65627           2.94070           0.27739
# 'ZYX'                2.66150           0.31383           0.00000
# 'ZZEF1'              0.00000           1.03490           0.00000
# 'ZZZ3'               0.00000           0.00000           0.00000
#
#             MGH107neg_P1_E01  MGH107pos_P2_G09  MGH107neg_P1_D06
# 'A1BG'                2.4772           0.00000            0.0000
# 'A1BG-AS1'            0.0000           0.00000            0.0000
# 'A1CF'                0.0000           0.00000            0.0000
# 'A2M'                 0.0000           6.89990            0.0000
# 'A2M-AS1'             0.0000           0.00000            0.0000
# ...                      ...               ...               ...
# 'ZYG11A'              0.9381           0.47301            0.0000
# 'ZYG11B'              1.9464           0.48749            4.7947
# 'ZYX'                 0.0000           0.00000            0.0000
# 'ZZEF1'               0.0000           0.00000            1.8969
# 'ZZZ3'                4.7674           0.00000            0.0000
#
# [23686 rows x 6341 columns]

# %% [markdown]
# ## Library size

# %%
ls = np.sum(raw, axis=0)  # library size
ls.shape
# Out:
# (6341,)

# %%
sc.settings.set_figure_params(dpi=80)
sns.set(color_codes=True)

plt.figure(figsize=(8, 8))
sns.displot(np.log10(ls))
plt.title('Histogram of log10 of library size before filtering')
plt.ylabel('Frequency')
# Out:
# Text(6.205555555555547, 0.5, 'Frequency')

# %% [markdown]
# ## Number of cells per gene

# %%
num_cells = np.sum(raw>0, axis=1)

# Add 1 to those genes that are expressed in 0 cells for log calculation
num_cells[num_cells==0] = 1  
num_cells.shape
# Out:
# (23686,)

# %%
plt.figure(figsize=(8, 8))
sns.displot(np.log10(num_cells))
plt.ylabel('Density')
# Out:
# Text(-1.6694444444444532, 0.5, 'Density')

# %% [markdown]
# # Part 2. Batch correction and normalization

# %%
# Convert to AnnData
adata = sc.AnnData(raw.transpose())

# Add 'batch' column to Anndata.obs
adata.obs['batch'] = raw.columns.str[0:6].astype('category')

adata
# Out:
# AnnData object with n_obs × n_vars = 6341 × 23686
#     obs: 'batch'

# %%
# np.sum(np.isnan(adata.X))

# %%
adata.obs
# Out:
#                    batch
# MGH42_P7_A01      MGH42_
# MGH42_P7_A02      MGH42_
# MGH42_P7_A03      MGH42_
# MGH42_P7_A04      MGH42_
# MGH42_P7_A05      MGH42_
# ...                  ...
# MGH107neg_P2_C05  MGH107
# MGH107pos_P2_D07  MGH107
# MGH107neg_P1_E01  MGH107
# MGH107pos_P2_G09  MGH107
# MGH107neg_P1_D06  MGH107
#
# [6341 rows x 1 columns]

# %%
sc.pp.combat(adata, key='batch')
adata
# Out:
# Found 991 genes with zero variance.
# /home/myp2113/miniconda3/lib/python3.8/site-packages/scanpy/preprocessing/_combat.py:340: RuntimeWarning: invalid value encountered in true_divide
#   (abs(g_new - g_old) / g_old).max(), (abs(d_new - d_old) / d_old).max()
# /home/myp2113/miniconda3/lib/python3.8/site-packages/scanpy/preprocessing/_combat.py:340: RuntimeWarning: divide by zero encountered in true_divide
#   (abs(g_new - g_old) / g_old).max(), (abs(d_new - d_old) / d_old).max()
# AnnData object with n_obs × n_vars = 6341 × 23686
#     obs: 'batch'

# %%
threshold_cells = 3.5
threshold_genes = 2
sc.pp.filter_cells(adata, min_genes=10**threshold_cells)
sc.pp.filter_genes(adata, min_cells=10**threshold_genes)
# Out:
# /home/myp2113/miniconda3/lib/python3.8/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 6341 × 22695
#     obs: 'batch', 'n_genes'
#     var: 'n_cells'

# %%
# Normalization
sc.pp.normalize_total(adata)

# %%
# Double check the normalization result - each cell should have total counts = median_ls
adata.X.sum(axis=1)
# Out:
# array([15132.51169758, 15132.51169758, 15132.51169758, ...,
#        15132.51169758, 15132.51169758, 15132.51169758])

# %%
adata_out = adata.copy()
adata_out
# Out:
# AnnData object with n_obs × n_vars = 6341 × 22695
#     obs: 'batch', 'n_genes'
#     var: 'n_cells'

# %%
adata_out.X.sum(axis=1)
# Out:
# array([15132.51169758, 15132.51169758, 15132.51169758, ...,
#        15132.51169758, 15132.51169758, 15132.51169758])

# %% [markdown]
# # Part 3. Dimensionality reduction

# %%
sc.settings.set_figure_params(dpi=100)

# sc.pp.log1p(adata)
# # remove highly variable genes
# sc.pp.scale(adata, max_value=10)
# Use PCA and decide the number of principle components in Umap
sc.tl.pca(adata, n_comps=100, svd_solver='auto')

# %%
sc.pl.pca_variance_ratio(adata, n_pcs=100, log=True)

# %%
# Based on the figures above, choose the number of principle components

sc.pp.neighbors(adata, n_neighbors=50, n_pcs=30)
sc.tl.umap(adata)
sc.pl.umap(adata)

# %% [markdown]
# # Part 4. Cluster cells based on marker genes

# %%
sc.tl.leiden(adata, resolution=0.1)
adata.obs
# Out:
#                    batch  n_genes leiden
# MGH42_P7_A01      MGH42_    14383      1
# MGH42_P7_A02      MGH42_    13770      1
# MGH42_P7_A03      MGH42_    14903      0
# MGH42_P7_A04      MGH42_    14319      1
# MGH42_P7_A05      MGH42_    14302      0
# ...                  ...      ...    ...
# MGH107neg_P2_C05  MGH107    19143      0
# MGH107pos_P2_D07  MGH107    19112      1
# MGH107neg_P1_E01  MGH107    18752      0
# MGH107pos_P2_G09  MGH107    19185      1
# MGH107neg_P1_D06  MGH107    18648      0
#
# [6341 rows x 3 columns]

# %%
adata.obs.leiden
# Out:
# MGH42_P7_A01        1
# MGH42_P7_A02        1
# MGH42_P7_A03        0
# MGH42_P7_A04        1
# MGH42_P7_A05        0
#                    ..
# MGH107neg_P2_C05    0
# MGH107pos_P2_D07    1
# MGH107neg_P1_E01    0
# MGH107pos_P2_G09    1
# MGH107neg_P1_D06    0
# Name: leiden, Length: 6341, dtype: category
# Categories (4, object): ['0', '1', '2', '3']

# %%
sc.pl.umap(adata, color='leiden')

# %%
sc.pl.umap(adata, color='batch')

# %%
# Decide what marker genes to be marked for each cluster
sc.settings.set_figure_params(dpi=150)
marker_genes = [
                "'IDH1'",
                "'EGFR'",
                "'NOVA1'",  # tumor cell markers
                "'UCHL1'",
                "'CD14'",   # macrophage markers
                "'CD68'",
                "'CD74'",
                "'VWF'",    # endothelial markers
                # "'CLDN5'"
                ]

sc.pl.dotplot(adata, marker_genes, groupby='leiden')
# Out:
# /home/myp2113/miniconda3/lib/python3.8/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):

# %%
sc.pl.umap(adata, color=["'IDH1'"])

# %%
cluster_names = [
                 'Transformed1', #0
                 'Macrophage1', #2
                 'Macrophage2', #3
                 'Transformed2' #4
                ]
adata.rename_categories('leiden', cluster_names)

sc.settings.set_figure_params(dpi=200)
sc.pl.umap(adata, color='leiden', legend_loc='on data', 
           title='', legend_fontsize=8)

# %%
adata.obs.groupby('leiden').count()
# Out:
#               batch  n_genes
# leiden
# Transformed1   5231     5231
# Macrophage1     701      701
# Macrophage2     308      308
# Transformed2    101      101

# %%
adata.obs
# Out:
#                    batch  n_genes        leiden
# MGH42_P7_A01      MGH42_    14383   Macrophage1
# MGH42_P7_A02      MGH42_    13770   Macrophage1
# MGH42_P7_A03      MGH42_    14903  Transformed1
# MGH42_P7_A04      MGH42_    14319   Macrophage1
# MGH42_P7_A05      MGH42_    14302  Transformed1
# ...                  ...      ...           ...
# MGH107neg_P2_C05  MGH107    19143  Transformed1
# MGH107pos_P2_D07  MGH107    19112   Macrophage1
# MGH107neg_P1_E01  MGH107    18752  Transformed1
# MGH107pos_P2_G09  MGH107    19185   Macrophage1
# MGH107neg_P1_D06  MGH107    18648  Transformed1
#
# [6341 rows x 3 columns]

# %%
# adata.obs.to_csv(DATA/"GSE89567_annotation_in_leiden.csv")

# %%
mtx = pd.DataFrame(adata_out.X.transpose(), 
                              index=adata_out.var.index, 
                              columns=adata_out.obs.index)
mtx
# Out:
#             MGH42_P7_A01  MGH42_P7_A02  MGH42_P7_A03  MGH42_P7_A04  \
# 'A1BG'          1.187306     -0.026585     -0.016561     -0.023655
# 'A1BG-AS1'      0.012710      0.013485      0.008401      0.011999
# 'A1CF'         -0.004258      0.103494     -0.002814     -0.004019
# 'A2M'           6.049037      6.974504      0.153306      6.210234
# 'A2M-AS1'      -0.039227     -0.041620     -0.025927     -0.037032
# ...                  ...           ...           ...           ...
# 'ZYG11A'        0.015051      0.457398      0.362348      0.173726
# 'ZYG11B'        0.228959      0.437343      2.151582      1.429455
# 'ZYX'           2.849762      2.302114     -0.149764      3.914058
# 'ZZEF1'         0.665783      1.241416     -0.113520     -0.162144
# 'ZZZ3'          0.172060      0.182556      3.089583      0.162434
#
#             MGH42_P7_A05  MGH42_P7_A07  MGH42_P7_A09  MGH42_P7_A11  \
# 'A1BG'         -0.017968      0.440905     -0.019386     -0.025668
# 'A1BG-AS1'      0.009114      0.008556      0.009833      0.013020
# 'A1CF'         -0.003053     -0.002866     -0.003294     -0.004361
# 'A2M'          -0.346092     -0.324905     -0.176107      7.259118
# 'A2M-AS1'       1.378180      1.527687     -0.030349     -0.040184
# ...                  ...           ...           ...           ...
# 'ZYG11A'        0.393123      0.207040      0.148000      0.321963
# 'ZYG11B'        3.021277      1.389089      2.196286      0.703238
# 'ZYX'           2.957805      2.308556      2.669876      3.469968
# 'ZZEF1'         1.182362      0.802515      1.976049      2.677715
# 'ZZZ3'          4.843932      3.474084      0.133120      0.176258
#
#             MGH42_P7_A12  MGH42_P7_B02  ...  MGH107neg_P2_E06  \
# 'A1BG'         -0.029796     -0.027891  ...          0.034473
# 'A1BG-AS1'      0.015114      0.014147  ...          0.048256
# 'A1CF'         -0.005063     -0.004739  ...          0.002579
# 'A2M'           6.665734      6.652558  ...         -0.038855
# 'A2M-AS1'      -0.046647     -0.043663  ...          0.014730
# ...                  ...           ...  ...               ...
# 'ZYG11A'        0.478094      0.324181  ...          0.228845
# 'ZYG11B'        0.060406      0.092534  ...          0.405037
# 'ZYX'           1.263999      0.293002  ...          4.348097
# 'ZZEF1'         0.428085      2.474714  ...          0.203726
# 'ZZZ3'          0.204606      1.141506  ...          0.227521
#
#             MGH107pos_P2_B03  MGH107neg_P1_F03  MGH107neg_P1_G06  \
# 'A1BG'              0.045309          0.034028          0.035759
# 'A1BG-AS1'          0.063424          0.047633          0.050056
# 'A1CF'              0.003390          0.002546          0.002675
# 'A2M'               8.218396         -0.038353         -0.040304
# 'A2M-AS1'           0.019360          0.014540          0.015279
# ...                      ...               ...               ...
# 'ZYG11A'            0.118412          0.497489          0.304984
# 'ZYG11B'            0.869796          0.431672          0.692421
# 'ZYX'               0.613193          0.460520          0.483944
# 'ZZEF1'             0.164966          2.348492          1.826521
# 'ZZZ3'              0.299041          0.786116          0.236009
#
#             MGH107neg_P2_H03  MGH107neg_P2_C05  MGH107pos_P2_D07  \
# 'A1BG'              0.040779          0.033050          0.051670
# 'A1BG-AS1'          0.057084          0.807847          0.072329
# 'A1CF'              0.003051          0.002473          0.003866
# 'A2M'              -0.045963         -0.037252         10.384298
# 'A2M-AS1'           0.017425          0.014122          0.022078
# ...                      ...               ...               ...
# 'ZYG11A'            0.604312          0.132459          0.135036
# 'ZYG11B'            1.003609          2.804742          0.755299
# 'ZYX'               3.714365          0.749517          0.699279
# 'ZZEF1'             0.148474          0.845471          0.188125
# 'ZZZ3'              0.269146          0.218134          0.341024
#
#             MGH107neg_P1_E01  MGH107pos_P2_G09  MGH107neg_P1_D06
# 'A1BG'              2.074615          0.052273          0.036441
# 'A1BG-AS1'          0.047396          0.073173          0.051011
# 'A1CF'              0.002533          0.003911          0.002726
# 'A2M'              -0.038163          7.591422         -0.041074
# 'A2M-AS1'           0.014467          0.022336          0.015571
# ...                      ...               ...               ...
# 'ZYG11A'            0.977380          0.716904         -0.061768
# 'ZYG11B'            1.985410          1.053775          4.874466
# 'ZYX'               0.458232          0.707438          0.493183
# 'ZZEF1'             0.123277          0.190320          1.598175
# 'ZZZ3'              4.363631          0.345003          0.240515
#
# [22695 rows x 6341 columns]

# %%
# mtx.to_csv(DATA/"GSE89567_normalized_batchcorrected.csv.gz", compression='gzip')
